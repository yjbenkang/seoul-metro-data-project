# %%
# !pip install requests boto3
# !pip install python-dotenv
# Out:
# Requirement already satisfied: requests in /Users/yjbenkang/miniconda3/lib/python3.12/site-packages (2.31.0)
# Requirement already satisfied: boto3 in /Users/yjbenkang/miniconda3/lib/python3.12/site-packages (1.35.54)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/yjbenkang/miniconda3/lib/python3.12/site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/yjbenkang/miniconda3/lib/python3.12/site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/yjbenkang/miniconda3/lib/python3.12/site-packages (from requests) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/yjbenkang/miniconda3/lib/python3.12/site-packages (from requests) (2024.8.30)
# Requirement already satisfied: botocore<1.36.0,>=1.35.54 in /Users/yjbenkang/miniconda3/lib/python3.12/site-packages (from boto3) (1.35.54)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/yjbenkang/miniconda3/lib/python3.12/site-packages (from boto3) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /Users/yjbenkang/miniconda3/lib/python3.12/site-packages (from boto3) (0.10.3)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /Users/yjbenkang/miniconda3/lib/python3.12/site-packages (from botocore<1.36.0,>=1.35.54->boto3) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/yjbenkang/miniconda3/lib/python3.12/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.36.0,>=1.35.54->boto3) (1.16.0)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: python-dotenv in /Users/yjbenkang/miniconda3/lib/python3.12/site-packages (1.0.1)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
import requests
import boto3
import pandas as pd
from io import BytesIO
import os 
from dotenv import load_dotenv

# %%
load_dotenv()
api_key = os.getenv("API_KEY")
base_url = os.getenv("BASE_URL")
aws_access_key_id=os.getenv('S3_AWS_ACCESS_KEY_ID')
aws_secret_access_key=os.getenv('S3_AWS_SECRET_ACCESS_KEY')
region_name=os.getenv('S3_REGION')
bucket_name = os.getenv('S3_BUCKET_NAME')

# %%
s3_client = boto3.client(
    's3',
    aws_access_key_id=aws_access_key_id,
    aws_secret_access_key=aws_secret_access_key,
    region_name=region_name
)

# %%
column_mapping = {
    '06-07시간대': 'time_06_07',
    '06시이전': 'before_06',
    '07-08시간대': 'time_07_08',
    '08-09시간대': 'time_08_09',
    '09-10시간대': 'time_09_10',
    '10-11시간대': 'time_10_11',
    '11-12시간대': 'time_11_12',
    '12-13시간대': 'time_12_13',
    '13-14시간대': 'time_13_14',
    '14-15시간대': 'time_14_15',
    '15-16시간대': 'time_15_16',
    '16-17시간대': 'time_16_17',
    '17-18시간대': 'time_17_18',
    '18-19시간대': 'time_18_19',
    '19-20시간대': 'time_19_20',
    '20-21시간대': 'time_20_21',
    '21-22시간대': 'time_21_22',
    '22-23시간대': 'time_22_23',
    '23-24시간대': 'time_23_24',
    '24시이후': 'after_24',
    '수송일자': 'transport_date',
    '승하차구분': 'boarding_type',
    '역명': 'station_name',
    '역번호': 'station_id',
    '호선': 'line',
}

# %%
def fetch_hourly_subway_passengers(endpoint: str):
    """
    역별 일별 시간대별 승하차 인원의 여러 API 엔드포인트에서 데이터를 가져옵니다.
    :param endpoint (str): 데이터를 가져올 API 엔드포인트.
    """
    all_data = pd.DataFrame()
    page = 1
    per_page = 1000
    while True:
        url = f"{base_url}{endpoint}?page={page}&perPage={per_page}&serviceKey={api_key}"
        response = requests.get(url)
        if response.status_code != 200:
            print(f"Failed to fetch data from {endpoint} on page {page}: {response.status_code}")
            break
        data = response.json()
        if 'data' not in data or not data['data']:
            print(f"No more data to fetch for {endpoint}.")
            break
        df = pd.DataFrame(data['data'])
        df.rename(columns=column_mapping, inplace=True)
        if 'transport_date' in df.columns:
            df['transport_date'] = pd.to_datetime(df['transport_date'])
            df['weekday'] = df['transport_date'].dt.dayofweek
        if '연번' in df.columns:
            df.drop(columns=['연번'], inplace=True)
        all_data = pd.concat([all_data, df], ignore_index=True)
        print(f"{endpoint} - Page {page} data fetched and added.")
        page += 1

    # 최종 데이터를 CSV로 변환하고 S3에 업로드
    csv_buffer = BytesIO()
    all_data.to_csv(csv_buffer, index=False, encoding='utf-8')
    csv_buffer.seek(0)
    return csv_buffer

def save_to_s3(csv_buffer : BytesIO, bucket_name : str, output_file : str):
    """
    s3에 csv파일을 저장합니다.
    :param csv_buffer (list): 데이터를 가져올 API 엔드포인트 목록.
    :param bucket_name (str): s3 버킷 이름
    :param output_file (str): 저장할 파일 이름
    """
    try:
        s3_client.upload_fileobj(csv_buffer, bucket_name, output_file)
        print(f"모든 데이터가 {output_file} 파일로 S3에 성공적으로 업로드되었습니다.")
    except Exception as e:
        print(f"Failed to upload combined data to S3: {e}")
        
def fetch_and_save_data(endpoint: str, bucket_name: str, output_file: str):
    """
    fetch_hourhly_subway_passengers save_to_s3를 호출하여 데이터를 가져와서 s3에 저장합니다.
    :param api_endpoint (str): 데이터를 가져올 API 엔드포인트.
    :param bucket_name (str): s3 버킷 이름
    :param output_file {str}: 저장할 파일 이름
    """
    csv_buffer = fetch_hourly_subway_passengers(endpoint)
    save_to_s3(csv_buffer, bucket_name, output_file)

api_endpoint = "/15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355"
output_file = "prod_data/서울교통공사_역별_일별_시간대별_승하차인원정보_전체데이터.csv"
all_data = fetch_and_save_data(api_endpoint, bucket_name, output_file)
# Out:
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 1 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 2 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 3 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 4 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 5 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 6 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 7 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 8 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 9 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 10 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 11 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 12 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 13 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 14 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 15 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 16 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 17 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 18 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 19 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 20 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 21 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 22 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 23 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 24 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 25 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 26 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 27 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 28 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 29 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 30 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 31 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 32 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 33 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 34 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 35 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 36 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 37 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 38 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 39 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 40 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 41 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 42 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 43 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 44 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 45 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 46 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 47 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 48 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 49 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 50 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 51 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 52 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 53 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 54 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 55 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 56 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 57 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 58 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 59 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 60 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 61 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 62 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 63 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 64 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 65 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 66 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 67 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 68 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 69 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 70 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 71 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 72 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 73 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 74 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 75 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 76 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 77 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 78 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 79 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 80 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 81 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 82 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 83 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 84 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 85 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 86 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 87 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 88 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 89 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 90 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 91 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 92 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 93 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 94 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 95 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 96 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 97 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 98 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 99 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 100 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 101 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 102 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 103 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 104 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 105 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 106 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 107 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 108 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 109 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 110 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 111 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 112 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 113 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 114 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 115 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 116 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 117 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 118 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 119 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 120 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 121 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 122 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 123 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 124 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 125 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 126 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 127 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 128 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 129 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 130 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 131 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 132 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 133 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 134 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 135 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 136 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 137 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 138 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 139 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 140 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 141 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 142 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 143 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 144 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 145 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 146 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 147 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 148 data fetched and added.
# /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355 - Page 149 data fetched and added.
# No more data to fetch for /15048032/v1/uddi:bff5665b-6c0b-4d2f-80ff-9af01761c355.
# 모든 데이터가 prod_data/서울교통공사_역별_일별_시간대별_승하차인원정보_전체데이터.csv 파일로 S3에 성공적으로 업로드되었습니다.
